# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/AI BATCH/DEEP_LEARNING/healthcare-dataset-stroke-data (1).csv")

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#df = pd.DataFrame(
 #   data=breast_cancer_dataset.data,
  #  columns=breast_cancer_dataset.feature_names
#)
#df['target']=breast_cancer_dataset.target
#df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df['stroke'].value_counts()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer # Import SimpleImputer for handling missing values

# Impute missing values in X_train before applying SMOTE
imputer = SimpleImputer(strategy='mean') # Using mean strategy as a common approach for numerical data
X_train_imputed = imputer.fit_transform(X_train)

X_resampled, y_resampled = SMOTE().fit_resample(X_train_imputed, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_839/2033853480.py in <cell line: 0>()
#       4 # Impute missing values in X_train before applying SMOTE
#       5 imputer = SimpleImputer(strategy='mean') # Using mean strategy as a common approach for numerical data
# ----> 6 X_train_imputed = imputer.fit_transform(X_train)
#       7
#       8 X_resampled, y_resampled = SMOTE().fit_resample(X_train_imputed, y_train)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.impute import SimpleImputer

# %%
out=['age','hypertension','hypertension','avg_glucose_level']

for i in out:
  Q1=df[i].quantile(0.25)
  Q3=df[i].quantile(0.75)
  IQR=Q3-Q1

  lb = Q1 - 1.5*IQR
  ub = Q3 + 1.5*IQR

  df=df[(lb<=df[i]) & (ub>=df[i])]

# %%
from sklearn.preprocessing import  LabelEncoder
le=LabelEncoder()
for i in df.columns:
  if df[i].dtypes == "object":
    df[i]=le.fit_transform(df[i])

# %%
X=df.drop('stroke',axis=1)
y=df['stroke']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
x_scaled=StandardScaler()
train_data=x_scaled.fit_transform(X_train,y_train)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Standardize training data
X_train_scaled = scaler.fit_transform(X_train)

# Standardize test data
X_test_scaled = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model= keras.Sequential([
    keras.layers.Dense(20,activation='relu', input_shape=(11,)), # Removed Flatten and set input_shape here
    keras.layers.Dense(2,activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model
# Out:
# <Sequential name=sequential, built=True>

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(X_train_scaled,y_train,validation_split=0.1,epochs=15)
# Out:
# Epoch 1/15
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9624 - loss: nan - val_accuracy: 0.9862 - val_loss: nan
# Epoch 2/15
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: nan - val_accuracy: 0.9862 - val_loss: nan
# Epoch 3/15
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: nan - val_accuracy: 0.9862 - val_loss: nan
# Epoch 4/15
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: nan - val_accuracy: 0.9862 - val_loss: nan
# Epoch 5/15
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: nan - val_accuracy: 0.9862 - val_loss: nan
# Epoch 6/15
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: nan - val_accuracy: 0.9862 - val_loss: nan
# Epoch 7/15
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: nan - val_accuracy: 0.9862 - val_loss: nan
# Epoch 8/15
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9723 - loss: nan - val_accuracy: 0.9862 - val_loss: nan
# ...

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("accuracy comparision")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training data','validation data'],loc='lower right')
